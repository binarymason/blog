# %%
# hide
from PIL import Image
from pathlib import Path

# %% [markdown]
# # It works

# %%
Image.open(Path.home()/"Pictures"/"patrick.gif")
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=498x278 at 0x7F6A584C74F0>
