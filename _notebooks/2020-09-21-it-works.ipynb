# %%
# hide
from PIL import Image
from pathlib import Path

# %% [markdown]
# # It works
# - categories: [test]

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ![patrick.gif](attachment:patrick.gif)
